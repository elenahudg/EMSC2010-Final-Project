# %% [markdown]
# <a href="https://colab.research.google.com/github/elenahudg/EMSC2010-Final-Project/blob/main/EMSC2010_Individual_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # EMSC2010 Individual Project
#
# ### Acid Rain: An analysis of the effectiveness of ___ intervention

# %% [markdown]
# ### 1. Project Overview:

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
spreadsheet_name = 'Surface_water_AR_USA.xlsx' # Name of the Excel file containing the ice melt data.
Sheet1 = 'Data' # Name of the worksheet containing the data.

# %%
surface_water = pd.read_excel(
    spreadsheet_name,   # Pass the variable holding the Excel file name to 'read_excel'.
    sheet_name=Sheet1,  # Specify the sheet named 'Sheet1' to read data for surface water, not metadata
    index_col='SITE_ID'
)
surface_water.head() # Display the first few rows of the created DataFrame to verify data loading and structure.
# Out:
#            PROGRAM_ID   DATE_SMP SAMPLE_LOCATION SAMPLE_TYPE WATERBODY_TYPE  \
# SITE_ID
# 070728       LTM_ALTM 2024-09-23             EPI     Regular         Stream
# 01434021      LTM_CAT 2024-09-19          Stream     Regular         Stream
# 0143400680    LTM_CAT 2024-09-19          Stream     Regular         Stream
# 01434025      LTM_CAT 2024-09-19          Stream     Regular         Stream
# 01364959      LTM_CAT 2024-09-19          Stream     Regular         Stream
#
#             SAMPLE_DEPTH TIME_SMP  AL_DS  AL_IM     AL_MON  ...  N_TD_UEQ_L  \
# SITE_ID                                                     ...
# 070728               0.0    06:20    NaN    NaN   7.393416  ...         NaN
# 01434021             NaN      NaN    NaN    NaN  47.760388  ...         NaN
# 0143400680           NaN      NaN    NaN    NaN  16.972477  ...         NaN
# 01434025             NaN      NaN    NaN    NaN   5.207771  ...         NaN
# ...

# %%
rows = surface_water.loc["1C1-090"] #Extract only the rows for the one site I am tracking over the years
# Out:
#         PROGRAM_ID   DATE_SMP SAMPLE_LOCATION SAMPLE_TYPE WATERBODY_TYPE  \
# SITE_ID
# 1C1-090     LTM_VT 2023-11-08             EPI     Regular           Lake
# 1C1-090     LTM_VT 2023-08-11             EPI     Regular           Lake
# 1C1-090     LTM_VT 2023-04-21             EPI     Regular           Lake
# 1C1-090     LTM_VT 2022-10-25             EPI     Regular           Lake
# 1C1-090     LTM_VT 2022-08-03             EPI     Regular           Lake
# ...            ...        ...             ...         ...            ...
# 1C1-090     LTM_VT 1980-10-14             EPI     Regular           Lake
# 1C1-090     LTM_VT 1980-08-18             EPI     Regular           Lake
# 1C1-090     LTM_VT 1980-07-21             EPI     Regular           Lake
# 1C1-090     LTM_VT 1980-06-17             EPI     Regular           Lake
# 1C1-090     LTM_VT 1980-02-20             EPI     Regular           Lake
#
#          SAMPLE_DEPTH TIME_SMP  AL_DS  AL_IM  AL_MON  ...  N_TD_UEQ_L  PH_EQ  \
# ...

# %%
plt.plot(rows["DATE_SMP"], rows['SO4_UEQ_L'])
